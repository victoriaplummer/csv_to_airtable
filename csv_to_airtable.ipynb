# %% [markdown]
# ## What Does this Example Do?
# This project should load data from a CSV hosted from 'somewhere' and update/create new records in Airtable

# %%
import os
import pandas as pd
import pyairtable # to interact with Airtable METADATA API
from pyairtable import Table, Api, Base, metadata # to interact with Airtable REST API
from dotenv import load_dotenv # to load .env files with environment variables
import yaml # to read config files
import requests
from requests.auth import HTTPBasicAuth

# Load .env files
load_dotenv()

# Read Config File
with open("config.yaml", "r") as yamlfile:
    config = yaml.load(yamlfile, Loader=yaml.FullLoader)
    print("Config Read successful")
# Out:
# Config Read successful

# %% [markdown]
# ## Get data from your source
# - Authenticate with source
# - Get data
# - Transform into JSON

# %%
# Work with DataSource team to navigate authentication with DataSource
username = "username"
password = "password"

 # Download File ()
csv_url = 'https://raw.githubusercontent.com/fivethirtyeight/data/master/comic-characters/marvel-wikia-data.csv'
df = pd.read_csv(csv_url)

# Convert to JSON
df.to_json("data.json", indent =4, orient = "records", date_format = "epoch", double_precision = 10, force_ascii = True, date_unit = "ms", default_handler = None)
data = pd.read_json("data.json")

# Rename Header Row with Name from Config File
rename_dict = config[0]['FieldNames']
renamed_data = data.rename(rename_dict, axis =1)

# Remove Null / NA Values
prepped_data = renamed_data.fillna({"GSM":"", "Year of First Appearance":0}) # Change this line to reflect your dataset
prepped_data_dict = prepped_data.to_dict('records')

# %% [markdown]
# ## Update Values in Airtable
# - [Example Base](https://airtable.com/invite/l?inviteId=inv0QZYyRSLsRVYGv&inviteToken=09a62e5c72983bc5245f6b34b78fc11d5da7f0794ac3816d190a7dfbd469bf2e&utm_source=email)
# - Using typecast = True, will allow you to easily create new Select Options and Linked Records when needed.

# %%
# Configuration variables for Airtable
AIRTABLE_API_KEY = os.environ['AIRTABLE_API_KEY']
AIRTABLE_BASE_ID = os.environ['AIRTABLE_BASE_ID']
AIRTABLE_TABLE_ID = os.environ['AIRTABLE_TABLE_ID']
AIRTABLE_UNIQUE_FIELD_NAME = os.environ['AIRTABLE_UNIQUE_FIELD_NAME']

# Initialize Airtable client
api = Api(AIRTABLE_API_KEY)
Table = Table(AIRTABLE_API_KEY, AIRTABLE_BASE_ID, AIRTABLE_TABLE_ID)

# Define input records(from the source system). This would usually be an API call or reading in a CSV or other format of data.
inputRecords = prepped_data_dict

# Retrieve all existing records from the base through the Airtable REST API
allExistingRecords = Table.all()
print('{} existing records found'.format(len(allExistingRecords)))

# Create an object mapping of the primary field to the record ID
# Remember, it's assumed that the AIRTABLE_UNIQUE_FIELD_NAME field is truly unique
upsertFieldValueToExistingRecordId = {
    existingRecord['fields'].get(AIRTABLE_UNIQUE_FIELD_NAME): existingRecord['id'] for existingRecord in allExistingRecords
}

# Create two arrays: one for records to be created, one for records to be updated
recordsToCreate = []
recordsToUpdate = []

# For each input record, check if it exists in the existing records. If it does, update it. If it does not, create it.
print('\nProcessing {} input records to determine whether to update or create'.format(
    len(inputRecords)))
for inputRecord in inputRecords:
    recordUniqueValue = inputRecord.get(AIRTABLE_UNIQUE_FIELD_NAME, None)
    print('\tProcessing record w / \'{}\' === \'{}\''.format(
        AIRTABLE_UNIQUE_FIELD_NAME, recordUniqueValue))

    existingRecordIdBasedOnUpsertFieldValueMaybe = upsertFieldValueToExistingRecordId.get(
        recordUniqueValue)

    # and if the upsert field value matches an existing one...
    if existingRecordIdBasedOnUpsertFieldValueMaybe:
        # Add record to list of records to update
        print('\t\tExisting record w / ID {} found; adding to recordsToUpdate'.format(
            existingRecordIdBasedOnUpsertFieldValueMaybe))
        recordsToUpdate.append(
            dict(id=existingRecordIdBasedOnUpsertFieldValueMaybe, fields=inputRecord))
    else:
        # Otherwise, add record to list of records to create
        print('\t\tNo existing records match; adding to recordsToCreate')
        recordsToCreate.append(inputRecord)

# Read out array sizes
print("\n{} records to create".format(len(recordsToCreate)))
print("{} records to update".format(len(recordsToUpdate)))

# Perform record creation - typecast = True to crete new Single Select Options
Table.batch_create(recordsToCreate, typecast=True)

# Perform record updates on existing records - typecast = True to crete new Single Select Options
Table.batch_update(recordsToUpdate, typecast=True)

print("\n\nScript execution complete!")
# Out:
# 6890 existing records found
#
# Processing 16376 input records to determine whether to update or create
# 	Processing record w / 'Page ID' === '1678'
# 		Existing record w / ID reckoaPutjduwmRlj found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '7139'
# 		Existing record w / ID recFFNnWdC4EZ5ChP found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '64786'
# 		Existing record w / ID rec77rx6dMZkW2RBp found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1868'
# 		Existing record w / ID rec7cjqdYKs4hoesf found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2460'
# 		Existing record w / ID reco51ggkSssRIuw6 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2458'
# 		Existing record w / ID rece2yLcWRc7LudIG found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2166'
# 		Existing record w / ID reckDzscZAeOANv6I found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1833'
# 		Existing record w / ID recLS4lO05kf4mfeL found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '29481'
# 		Existing record w / ID recHzxzLdT1b0hGvr found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1837'
# 		Existing record w / ID recIVgRLyctokwjpb found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '15725'
# 		Existing record w / ID rec23t4zRfqz0iscb found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1863'
# 		Existing record w / ID recfG5GX3cNjzrBxu found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '7823'
# 		Existing record w / ID recrdvtqlqif5lMTP found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2614'
# 		Existing record w / ID recnCr8p0uzfFOHjz found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1803'
# 		Existing record w / ID rec9PJN6Wx03idV44 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1396'
# 		Existing record w / ID rec7OgWlrJCmfbwld found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '55534'
# 		Existing record w / ID reczSaNpQQzuEzeAu found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1978'
# 		Existing record w / ID recfYSiiV8m1Ap1un found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1872'
# 		Existing record w / ID recKmTxeYOWZTv7hj found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '35350'
# 		Existing record w / ID recDeI39rlL623oCL found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1557'
# 		Existing record w / ID recex5Nbi5kbRtkje found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '65255'
# 		Existing record w / ID recLgjvhyL0a0OeiM found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1073'
# 		Existing record w / ID recMyblLZ2y9TgJ18 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1346'
# 		Existing record w / ID recZOoJkzhvNxojSI found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2512'
# 		Existing record w / ID rec8wNYMtaI1usmSk found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1671'
# 		Existing record w / ID recmAMMaQCfrGJ1BP found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1976'
# 		Existing record w / ID recGzoCvcoy8wjijX found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '65219'
# 		Existing record w / ID recEf7nEBgOv371fk found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '6545'
# 		Existing record w / ID recBQujWVZqPOQay0 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2223'
# 		Existing record w / ID recZ0NyXb9CrzGJ6K found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2414'
# 		Existing record w / ID recvmVknmx7QASEPB found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '8650'
# 		Existing record w / ID rec8rqSRi49IxWi8o found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2527'
# 		Existing record w / ID recHFUesWCFFUTAHJ found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1970'
# 		Existing record w / ID recEyFoApCx7EGfhB found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '37690'
# 		Existing record w / ID recQhUb6xjGyvH7fR found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '3765'
# 		Existing record w / ID reclTOzjr09PT1tsI found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2312'
# 		Existing record w / ID rectNhM9tEcHmvGYy found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1265'
# 		Existing record w / ID recGY8zGrmdwov50X found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1677'
# 		Existing record w / ID recgE06G8izyFD5Mu found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '25222'
# 		Existing record w / ID recupXq2pqhqzED2h found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '6537'
# 		Existing record w / ID rechWlh3gZNMdqdI6 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1592'
# 		Existing record w / ID recvnnujeahpI4CHV found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1818'
# 		Existing record w / ID recGkzGKZ910Clfzx found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1448'
# 		Existing record w / ID recHzgfM1sp0ei4Ia found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2081'
# 		Existing record w / ID recpV86u6lUxWguMm found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2307'
# 		Existing record w / ID rec43RtLCGzl5IHPA found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2556'
# 		Existing record w / ID recLdquuOjoKrREGX found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1740'
# 		Existing record w / ID recJ0uOWNeI0rtRTm found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '8651'
# 		Existing record w / ID recGeHgnO9K6d3Z3s found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2009'
# 		Existing record w / ID recEPwFxlONcwiBzS found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1276'
# 		Existing record w / ID reckWcVXAEIkxMmot found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '15823'
# 		Existing record w / ID recy5l8nimcjhEMNm found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1680'
# 		Existing record w / ID rec8Jkvy44lcZIvb1 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1866'
# 		Existing record w / ID rec89qH2SI0LZ4onv found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '32498'
# 		Existing record w / ID recYnlKajbM8va81P found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1772'
# 		Existing record w / ID reculaIZgMJXeaavv found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1896'
# 		Existing record w / ID recr3zeji4YR21nC3 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1496'
# 		Existing record w / ID recb66jylzD8cd8Kk found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1802'
# 		Existing record w / ID reccIrhUUTkp8iL8j found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1811'
# 		Existing record w / ID recTodAzUgYRedn9G found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1836'
# 		Existing record w / ID recwNs3SHr92wIRK5 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2042'
# 		Existing record w / ID recdgOqM7KQoRkat8 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1643'
# 		Existing record w / ID recjoy7Il5i3z03Xf found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1285'
# 		Existing record w / ID recoo5j0dboEjyjHe found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1453'
# 		Existing record w / ID recb66HjZnTzl2eJ0 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '6194'
# 		Existing record w / ID recZEMVA5ViFNRZuO found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1487'
# 		Existing record w / ID rec2dxwztwNxiVgfT found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1380'
# 		Existing record w / ID recMytR7TlhSObLDO found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1613'
# 		Existing record w / ID recQByxWsvg92XyQ6 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1931'
# 		Existing record w / ID recFoHBU0hANoOJG8 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1596'
# 		Existing record w / ID recluC1BAQ0h7IkRP found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1409'
# 		Existing record w / ID recifFcUIKFHdU5aK found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1187'
# 		Existing record w / ID recFK66C23y81msQ6 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1741'
# 		Existing record w / ID rec1ARYmpz1Cf2QqH found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '68416'
# 		Existing record w / ID recPdpX9nDLj9ZfCK found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2589'
# 		Existing record w / ID recnUU4ahkiahNPCH found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2626'
# 		Existing record w / ID recKQ4ZDb6omBQcbQ found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2007'
# 		Existing record w / ID recKfnTedS7nBYvvx found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1130'
# 		Existing record w / ID recc8UIdbxeKguxvt found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2278'
# 		Existing record w / ID rec4J4uCint5K0KFf found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '67048'
# 		Existing record w / ID recEfDNCcYfboP7Xc found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1705'
# 		Existing record w / ID recz37JR8Xzql5avY found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2550'
# 		Existing record w / ID recWZgt21O9R5HbYR found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2365'
# 		Existing record w / ID recQpZvT9B6mYgONQ found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1900'
# 		Existing record w / ID recURjbCfpgFhnkA2 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2420'
# 		Existing record w / ID recbMzLtM1H66Frkx found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1127'
# 		Existing record w / ID recAz8PStzRP1UE8Z found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1676'
# 		Existing record w / ID recHSe5trS06dKOfB found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1395'
# 		Existing record w / ID recBGjAwIIWNWNWpr found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2183'
# 		Existing record w / ID recChIgKkDdKCyP48 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1782'
# 		Existing record w / ID recQuYaD46uwyMgg9 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2137'
# 		Existing record w / ID recg31Es4H1pYbhNC found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2374'
# 		Existing record w / ID recyGsflOBwPKR0Vu found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2077'
# 		Existing record w / ID recfuVlh4DAtpLEq9 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2344'
# 		Existing record w / ID recB59dtCM4Oo00w6 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1616'
# 		Existing record w / ID recB11jtc4p6Qxr4h found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1131'
# 		Existing record w / ID recuBnXOMxXjGqYpa found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2487'
# 		Existing record w / ID recAcKlcqNA2j49MC found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1572'
# 		Existing record w / ID reciRGXWIVL6J1OrI found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2239'
# 		Existing record w / ID recppP56q8d4gz0BD found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1827'
# 		Existing record w / ID recgLFtcc1C4R31yV found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '55878'
# 		Existing record w / ID recJLnUi1OsnL72kG found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2173'
# 		Existing record w / ID rec9XJJDjiowUvCw4 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1179'
# 		Existing record w / ID rec76QhX0GJQyQKLM found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2392'
# 		Existing record w / ID recT5RwN52B9vAVmq found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1404'
# 		Existing record w / ID reckULGL5lmT43Twx found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '18186'
# 		Existing record w / ID recTBNY3EOH1Ub6ri found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1586'
# 		Existing record w / ID rec1p727oGCn5VuUL found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2440'
# 		Existing record w / ID rec0qJUTTQPhHXKn5 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2185'
# 		Existing record w / ID receBhrotZxrN9bLU found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2382'
# 		Existing record w / ID reccJtEryx8lEXdM0 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1300'
# 		Existing record w / ID recGsUqBUBJY6cbNp found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1180'
# 		Existing record w / ID recUgUBeZXivrm9TM found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1901'
# 		Existing record w / ID rect6vrq3h7txgdG4 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '37751'
# 		Existing record w / ID recXxSRO0XTsMcZ9y found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '20978'
# 		Existing record w / ID recnlwpMaMbdFatkQ found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1161'
# 		Existing record w / ID recy68GkNIaABv3Zy found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2182'
# 		Existing record w / ID rec7xgs7gj2FaHbQn found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '100209'
# 		Existing record w / ID recuONsdNy2SmdPo2 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1973'
# 		Existing record w / ID recqaXgWvbo81UQTK found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1633'
# 		Existing record w / ID recUBWDACbSbl8iYF found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '11857'
# 		Existing record w / ID recnCaCk2lHSlAAei found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2513'
# 		Existing record w / ID reczQxFi0lNim4gYc found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2146'
# 		Existing record w / ID rec66fDNtQTnu6okE found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '7630'
# 		Existing record w / ID recW5HLc2r9tU39fQ found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2238'
# 		Existing record w / ID recEoivEEOCMhnBvg found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1706'
# 		Existing record w / ID recbUDaY46n2weezp found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1460'
# 		Existing record w / ID recu4VlpMVIjv5Cop found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2010'
# 		Existing record w / ID recnS3dSoLPeBkhaB found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2456'
# 		Existing record w / ID recOYEt1JWU6t7A3s found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '15282'
# 		Existing record w / ID rec5OEzwdW8yOWTLW found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '4704'
# 		Existing record w / ID recS4cu0RhFsBF4zX found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '5708'
# 		Existing record w / ID recm1zrjoJ0AyX01n found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1902'
# 		Existing record w / ID recDnBCoMxLDORk3s found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '6633'
# 		Existing record w / ID recuTEVCcYQeklzyO found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '100716'
# 		Existing record w / ID recVkGJziVHxcJNMp found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '4565'
# 		Existing record w / ID rec8JoDzkofUsufoV found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1505'
# 		Existing record w / ID recDFNM9feCll0Ce7 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1256'
# 		Existing record w / ID recgXvFsTHYYTuSqQ found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '119507'
# 		Existing record w / ID recbTE7uuHOrU9s6A found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '9106'
# 		Existing record w / ID recdyeU9VFxArpSX8 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2383'
# 		Existing record w / ID reca4SFCIchK2whLl found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1733'
# 		Existing record w / ID recagyLsg4LtAf1Du found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '37689'
# 		Existing record w / ID reclaRSW3NjCPjlBc found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1808'
# 		Existing record w / ID rec4L92TVmUUByyLt found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2558'
# 		Existing record w / ID rechgbCMXrvBVrCJT found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1565'
# 		Existing record w / ID reczDEMQhoFObFbNb found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '33447'
# 		Existing record w / ID recKOjZj1wEhAgk94 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2511'
# 		Existing record w / ID recDD3hzXNwkJqpkQ found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1971'
# 		Existing record w / ID recNW0FRwJi7xm8Sl found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1903'
# 		Existing record w / ID recAGkWROciD6VyCs found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1445'
# 		Existing record w / ID recjOCi0pm20xn7v1 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2582'
# 		Existing record w / ID recJj9IPi4o7ciTSD found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2037'
# 		Existing record w / ID recqdPDCfZvr52kfz found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1935'
# 		Existing record w / ID recnTi19HI8QOGAUX found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2060'
# 		Existing record w / ID rec0k1UEU52wYVjHs found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1915'
# 		Existing record w / ID recE7TlH2gOIH5APL found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2204'
# 		Existing record w / ID recbejYKCdjgBRJ4K found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2038'
# 		Existing record w / ID recLOuJ0iGOYDvp5K found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1029'
# 		Existing record w / ID recJiLEpHt6loOM4m found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2407'
# 		Existing record w / ID recyu7Zzzmba8b0sV found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2034'
# 		Existing record w / ID recAhshCdjkYMEXxT found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2097'
# 		Existing record w / ID recZNk0eSejTHSx4d found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2421'
# 		Existing record w / ID recYSjAjJQWR3AqTY found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1514'
# 		Existing record w / ID recaBHoYvv8p4SFKD found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1335'
# 		Existing record w / ID recJURNA3RinlvACv found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1289'
# 		Existing record w / ID recE2vVwOt3KReGnD found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2309'
# 		Existing record w / ID rec8QplHRrII3YhcE found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1813'
# 		Existing record w / ID recAbB6IluekV2blR found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '76396'
# 		Existing record w / ID recs2EFYBhYNvfTqC found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2497'
# 		Existing record w / ID recyKhgDTkmvMOQvK found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2138'
# 		Existing record w / ID recnASxLJY6lbR7ya found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '6517'
# 		Existing record w / ID recgdfodLD5QQKQfq found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2351'
# 		Existing record w / ID rec09hRd1b6rAd5j7 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '15903'
# 		Existing record w / ID recuyzRzlUTihIBQv found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2335'
# 		Existing record w / ID recrfc0554wIE7Pep found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1095'
# 		Existing record w / ID recsUIjLsTMPf3guW found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2523'
# 		Existing record w / ID rec30y1XUy3UVPPp0 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2617'
# 		Existing record w / ID recqpkLw4lWH91LVy found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1533'
# 		Existing record w / ID recYoo78YHastGhFp found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2186'
# 		Existing record w / ID recU5A8kx2XKbVUDT found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2353'
# 		Existing record w / ID recy7BiAdWm5LRw4J found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '15511'
# 		Existing record w / ID rec4n0YSt0ZoC7IQl found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '15907'
# 		Existing record w / ID recMqkntf6qfpv5pv found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2724'
# 		Existing record w / ID recapQUp8k5oNIZTa found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1911'
# 		Existing record w / ID reckg6ldxYGu3YR72 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1336'
# 		Existing record w / ID recPrlQuzkyKlTU0c found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1503'
# 		Existing record w / ID recKA7H6b7wldFpEt found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1356'
# 		Existing record w / ID rec3N2fufWlVV9z14 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '8844'
# 		Existing record w / ID rec6DrNsUQl8UHCZj found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1471'
# 		Existing record w / ID recTwDUY5fgsmZSPv found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1389'
# 		Existing record w / ID rec4ppoFLJjkOQcG2 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2054'
# 		Existing record w / ID recVbAPKUEpFjqY6l found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1684'
# 		Existing record w / ID recCyYLB1mRvIBIDk found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '10174'
# 		Existing record w / ID rec0nVHKVDyFlssw9 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2590'
# 		Existing record w / ID recB8fwAOS6SZELtL found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1654'
# 		Existing record w / ID recX6EDX3VRHg4ogV found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2482'
# 		Existing record w / ID recAU1uhgwDVF5DrF found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1080'
# 		Existing record w / ID rec4vSGFsTH3ezVE4 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1840'
# 		Existing record w / ID rectZ3YExOgIO49KQ found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '8648'
# 		Existing record w / ID recTyPaqTMl7lsGZq found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1117'
# 		Existing record w / ID recSIYLwTa2RrQULA found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1122'
# 		Existing record w / ID recupHJ4jd0ufUNYB found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1027'
# 		Existing record w / ID recoshqYIk683mb5o found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '18854'
# 		Existing record w / ID rec3IkGfa6zCmgguZ found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2528'
# 		Existing record w / ID recQKWutEyFz9rgdA found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '119275'
# 		Existing record w / ID recTneSYgpCpkZlCj found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2470'
# 		Existing record w / ID rec0NEkO1Tx2auKLZ found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1544'
# 		Existing record w / ID recsBrH584sq17WBQ found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2501'
# 		Existing record w / ID recS3R3qafixpAFxW found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1888'
# 		Existing record w / ID recM7tvOnFF7d5zgm found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1215'
# 		Existing record w / ID recmLK1xscVIbP6nJ found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1204'
# 		Existing record w / ID reclck9TkXlHJm9cP found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1523'
# 		Existing record w / ID recbZsbXSaHlgaKgh found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1232'
# 		Existing record w / ID rece9p1ytknfmx5sz found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2099'
# 		Existing record w / ID recsfAyDsqPatu3x6 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2006'
# 		Existing record w / ID recEjZz4vhSteSy8X found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '51769'
# 		Existing record w / ID recM7Uy1O9Ag8kGM8 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1943'
# 		Existing record w / ID recV1Ig4BkmNa43hu found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1315'
# 		Existing record w / ID recn0fW6fkPkgOvTJ found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1142'
# 		Existing record w / ID recGkBKSKHcAJ4Z4h found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '15901'
# 		Existing record w / ID recavOoH6NOJRx9uX found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '4368'
# 		Existing record w / ID recs2jA70uGZDM20R found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1576'
# 		Existing record w / ID recET0yWk4Vx3sqm7 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1386'
# 		Existing record w / ID recUzBJ7JnBJiKmx6 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2715'
# 		Existing record w / ID recxdHcrVaihu3hIZ found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1822'
# 		Existing record w / ID recKoCm9LkWqKWsZw found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '39324'
# 		Existing record w / ID recOfw3EXyWB1nJzT found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1981'
# 		Existing record w / ID reckpQ4MepCGXshBg found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '39972'
# 		Existing record w / ID recmvsWD5Wm6tr5eF found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1354'
# 		Existing record w / ID rec7owGjp39pvKwid found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2065'
# 		Existing record w / ID recQpEYq7kPBvHy2e found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1344'
# 		Existing record w / ID recvotpSvW62Y4aVz found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '57563'
# 		Existing record w / ID recPPkxY3nJJlSshg found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1184'
# 		Existing record w / ID recSh0ZC9wLCHSAhh found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '57564'
# 		Existing record w / ID recfm8t9a3AYBCuev found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2376'
# 		Existing record w / ID recgyLR31NjKiVBYP found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2115'
# 		Existing record w / ID recfcQqnGVKUQOiJM found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '194870'
# 		Existing record w / ID recYo9h7SIFTDqYhT found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1809'
# 		Existing record w / ID recC2udLt3Ajq6HFW found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2024'
# 		Existing record w / ID rechBc5CncqdSqbc9 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1760'
# 		Existing record w / ID recWOHu6ZahJ2cSCJ found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '4877'
# 		Existing record w / ID recUvKmAW3SLbipRm found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '7975'
# 		Existing record w / ID recbbK8OiROqWe9UI found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '15257'
# 		Existing record w / ID recWQ0thLuyS015iZ found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1399'
# 		Existing record w / ID recx7uhG5c9xdCv1Z found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2178'
# 		Existing record w / ID rec3CxEIVsdYykttM found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1140'
# 		Existing record w / ID recyfTqKAIu9v0fUy found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2015'
# 		Existing record w / ID rec4WPdi834CaRU7G found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2271'
# 		Existing record w / ID recrVv3NBH6cKWTHf found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2428'
# 		Existing record w / ID recJb2p7xbfqdBJyl found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '19592'
# 		Existing record w / ID rec3cbqnIScDhHpaB found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1756'
# 		Existing record w / ID recoeYG6KR83J1lLO found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1874'
# 		Existing record w / ID recsAJSbXXxJXpy9O found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1715'
# 		Existing record w / ID recYqpXHUdoOMIqRT found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1084'
# 		Existing record w / ID rec99zLHBkRq7oT5I found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2624'
# 		Existing record w / ID recFk5xVCDqcZfv6L found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2554'
# 		Existing record w / ID rectyOotDlkCku8Rf found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '5398'
# 		Existing record w / ID recvFM5AGhV4URoA6 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '25255'
# 		Existing record w / ID recpDsl4r8q2l7xGD found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2168'
# 		Existing record w / ID recG92hDNzUcBcyEo found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1226'
# 		Existing record w / ID recrYO3wUf5yflBQp found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2105'
# 		Existing record w / ID recyCq3CK0U6fNt3E found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1057'
# 		Existing record w / ID reccecYhIHawNkTqU found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1435'
# 		Existing record w / ID rec5cxnMu14SqDC6a found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '119342'
# 		Existing record w / ID rec1fJyj9MjNWS2cN found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2170'
# 		Existing record w / ID recTvpttpsjKZqxRU found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1450'
# 		Existing record w / ID recnnjW4DotfcQFpx found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '68280'
# 		Existing record w / ID recvJC8r0dqG7yDH0 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1163'
# 		Existing record w / ID rec9btCwEWWvaYBUB found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1958'
# 		Existing record w / ID recgC3I4VuFRGxuHy found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1961'
# 		Existing record w / ID reco1WgQ0jHyY6swy found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2422'
# 		Existing record w / ID recyGQgwC4zBvwB5b found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '15209'
# 		Existing record w / ID recNbSejdlDCD65K1 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2494'
# 		Existing record w / ID recqcWm8dsKHfgK7j found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2023'
# 		Existing record w / ID recuUQhUrRosEjfxV found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2067'
# 		Existing record w / ID rechrAtWpEFad3fv5 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '41613'
# 		Existing record w / ID recP8XANfGDN1DC8m found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '79494'
# 		Existing record w / ID receMJb7ZnPHHIb9b found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1287'
# 		Existing record w / ID rec3uKOfVDS6SKKeT found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '16501'
# 		Existing record w / ID recoPDclasv7hZhhW found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1316'
# 		Existing record w / ID recqKNihmwFlfsneQ found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '9967'
# 		Existing record w / ID recdpxTTmSiCm7iMq found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2058'
# 		Existing record w / ID recrr1ezqV77nigda found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2072'
# 		Existing record w / ID recUQTL3MYNDgUqHU found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '101355'
# 		Existing record w / ID rec8ttz0JWnHTZtz8 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2543'
# 		Existing record w / ID recUwDIjCGtK0pSmt found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '9819'
# 		Existing record w / ID rec26fjCENs2QaPNr found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2320'
# 		Existing record w / ID recsN4b4DSGhlBz5v found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1933'
# 		Existing record w / ID recH3ScdUiuHwSAvp found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '15904'
# 		Existing record w / ID recr3giQpKdLau3dq found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '5592'
# 		Existing record w / ID recqUPP6DrRnB0Gt9 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2727'
# 		Existing record w / ID recnXWDMTUK1fTeyG found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2164'
# 		Existing record w / ID rectXMuea4db8yAYu found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2175'
# 		Existing record w / ID recsduQ1ONtwFM0Rt found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1891'
# 		Existing record w / ID recj69m0b8uGvt4cR found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2003'
# 		Existing record w / ID recE8qxtJlz3z7OKB found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '10309'
# 		Existing record w / ID recdieuqNoZOc9Y2o found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '39133'
# 		Existing record w / ID rect3ulBgLXrkHT5H found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1475'
# 		Existing record w / ID recx83gQwcbP00WG1 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2577'
# 		Existing record w / ID recjGT4xYh37yt7UX found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '7991'
# 		Existing record w / ID recEasJQ11vEKaMyF found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '83811'
# 		Existing record w / ID rec6g2s4xq3HG0jqE found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1904'
# 		Existing record w / ID rec4BTptR6UegjOhN found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2225'
# 		Existing record w / ID recD7LUoBRTDrdYWW found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2362'
# 		Existing record w / ID recAPr46hojW6O6Ti found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1071'
# 		Existing record w / ID recHNVIsbB6mt6hro found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '18135'
# 		Existing record w / ID rec7VENZzlN4vhhKG found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1352'
# 		Existing record w / ID recHzKO01Svr7RWbK found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2245'
# 		Existing record w / ID rec6bOuWnfMPnOb8I found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '535259'
# 		Existing record w / ID rec5jyxozINmyOmnY found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2061'
# 		Existing record w / ID rectxaER3waixBNod found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2737'
# 		Existing record w / ID recLgYJkPuIaY4xla found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2064'
# 		Existing record w / ID recvT5tHLHy01g94l found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '18656'
# 		Existing record w / ID recCyYx91dzhNTYgl found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '18275'
# 		Existing record w / ID recRnFIarFlbPE5ag found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1464'
# 		Existing record w / ID recHVgwmnEaxdBGrj found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2088'
# 		Existing record w / ID recHEUAM3u0XXPGJl found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '18271'
# 		Existing record w / ID rec9eXtRbCthH5mma found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '45178'
# 		Existing record w / ID recfFOEjAyTTBrXf5 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '7127'
# 		Existing record w / ID recZscnvqBwOeUlFj found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1881'
# 		Existing record w / ID rec6qAsA3lQ7enEb6 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '37620'
# 		Existing record w / ID rec4zzcqtKWtpHVM2 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '10485'
# 		Existing record w / ID recJyiBHz9eu6eSOm found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1090'
# 		Existing record w / ID recamvI013cr5xdz9 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '16003'
# 		Existing record w / ID recXY3LvodP60tFD1 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1916'
# 		Existing record w / ID recir3RkQ45XUA6On found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2596'
# 		Existing record w / ID rec2DhXZXRyNq2Xlx found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1267'
# 		Existing record w / ID recF7NSBMaoub9IWX found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1686'
# 		Existing record w / ID recNS5CXCzCnLO1Fq found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '4011'
# 		Existing record w / ID rec02oAi2ms6hzKTy found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2434'
# 		Existing record w / ID recebafcxvE3ORHkC found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1078'
# 		Existing record w / ID rec47iWCzZI9UIDKv found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '43031'
# 		Existing record w / ID recqH8racLTZRLFKD found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1876'
# 		Existing record w / ID recihbesu46Q5xpvI found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '22326'
# 		Existing record w / ID recd4qAjPevqp0dbW found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1488'
# 		Existing record w / ID recr04Ofb0jXhQ61Y found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1546'
# 		Existing record w / ID rec0HHj2T3nP22Tvu found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '19518'
# 		Existing record w / ID recjLADC24kexFCUS found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1068'
# 		Existing record w / ID recZ0yhtGo0mVSPol found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1036'
# 		Existing record w / ID reckfJ0rExwhsciMo found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '5395'
# 		Existing record w / ID rec7v5b9GxdJyvhIm found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '6635'
# 		Existing record w / ID rec1lEFJEjXaR7vHB found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2125'
# 		Existing record w / ID rec45loOHijOeQ0fu found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2612'
# 		Existing record w / ID recHKhW3wPuBOMOut found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '7584'
# 		Existing record w / ID rec226nn12tmySAyf found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '27860'
# 		Existing record w / ID recyDyWbeUIYUQcop found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2359'
# 		Existing record w / ID recNV2wRB952AFlyy found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '68317'
# 		Existing record w / ID recoOMXkwz9p4XZ1Z found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1146'
# 		Existing record w / ID recPUkpXHxNEv869N found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2002'
# 		Existing record w / ID recIj04ja1fylu4mM found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1254'
# 		Existing record w / ID rechbCBSawBHRgx9z found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '31525'
# 		Existing record w / ID recAK51CStP7cXnTf found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2110'
# 		Existing record w / ID recjdyB8qVU4b2hyY found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '117089'
# 		Existing record w / ID recbxGPW7JzwPEXnx found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '6637'
# 		Existing record w / ID recUserGCorYYc9hP found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1780'
# 		Existing record w / ID recmZHF2ycfsQ4YxF found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '54511'
# 		Existing record w / ID recObSDv8IzZx3gl3 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2474'
# 		Existing record w / ID rec7Z2kTc6AEvGGDl found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1786'
# 		Existing record w / ID recUGNh5UvJpZOaUJ found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1141'
# 		Existing record w / ID recqvRDQ9INSE7NLV found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1025'
# 		Existing record w / ID reclnCmij9AXe3hyg found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '16586'
# 		Existing record w / ID recNa0dg78G8oaToR found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '18175'
# 		Existing record w / ID recove6jVVnNL2taC found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1479'
# 		Existing record w / ID recHT5CxknufnmnQI found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1268'
# 		Existing record w / ID recGpN3Xkligo4Da0 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1463'
# 		Existing record w / ID recUBkrMgwFqwMBk7 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2484'
# 		Existing record w / ID rec8q2A4kRT0ReJ90 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1465'
# 		Existing record w / ID rec3Mf2dk9IRZBrhc found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2298'
# 		Existing record w / ID recvkM8KjYeDR1OJ3 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1816'
# 		Existing record w / ID recZwGQwPjDOKfOlB found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1618'
# 		Existing record w / ID recoTxg01bUQXOPwE found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2380'
# 		Existing record w / ID reciM5itwFShCoJGB found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2635'
# 		Existing record w / ID reci6xabBv670qNnR found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1091'
# 		Existing record w / ID recqq58kHN0JAgQak found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '4703'
# 		Existing record w / ID recNO33DNYXJOTOAP found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2029'
# 		Existing record w / ID rece0BMVhkao1xRvV found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1361'
# 		Existing record w / ID recrs81gA3Lr1zMPk found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '9851'
# 		Existing record w / ID recAaVslKTFcbQrEg found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1984'
# 		Existing record w / ID rec7Ka4EdjUEgD7CY found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2300'
# 		Existing record w / ID recsSDI0FEP2dMOAT found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1825'
# 		Existing record w / ID recV34SHgtVJy4aEs found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1124'
# 		Existing record w / ID recv2qhR3kVNPKNBF found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2317'
# 		Existing record w / ID recXQPhzQxpIXbDV9 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '5513'
# 		Existing record w / ID recPfTqMtC7f3e1tE found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2593'
# 		Existing record w / ID recQZ5XrKYCIcMd0t found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2561'
# 		Existing record w / ID recRB2lLuknYFnXvR found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '8930'
# 		Existing record w / ID recWQhWPaw6eKbZGf found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1610'
# 		Existing record w / ID recBXMK9UXuSqn9mO found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2389'
# 		Existing record w / ID recOG6jUIxIttr05i found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1877'
# 		Existing record w / ID recxOI0KXlxoDhEUZ found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '15587'
# 		Existing record w / ID recbWJGlvYhNE1Dhq found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1665'
# 		Existing record w / ID rec4jrwWv0hW8CSUj found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1849'
# 		Existing record w / ID recE10N0dJIHna6p0 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '2119'
# 		Existing record w / ID rec37wNlKNdSpdvnt found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '1515'
# 		Existing record w / ID recTNSJj21Nwfe6P0 found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '7628'
# 		Existing record w / ID rec4kADaBTKIjWq8w found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '14469'
# 		Existing record w / ID recdX838N2MMPaaWn found; adding to recordsToUpdate
# 	Processing record w / 'Page ID' === '29110'
# ...
# 	Processing record w / 'Page ID' === '18232'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '83232'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '95431'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '2098'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '506266'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '83302'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '508034'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '511838'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '511821'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '698944'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '557944'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '541449'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '2714'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '19578'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '56034'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '396358'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '93364'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '507282'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '118744'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '506005'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '501061'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '506000'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '191212'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '18226'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '89299'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '42113'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '505999'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '706191'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '556317'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '29015'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '13122'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '511679'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '735468'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '511682'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '511681'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '18524'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '511822'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '321666'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '505760'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '128730'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '43101'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '18468'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '726551'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '511678'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '511840'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '511841'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '511842'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '714409'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '511843'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '495431'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '47468'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '34672'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '511670'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '511669'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '557914'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '12780'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '511668'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '106202'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '78159'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '505972'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '421233'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '42866'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '89301'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '555923'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '42106'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '462671'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '725312'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '507239'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '40061'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '505759'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '16569'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '16296'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '120833'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '693077'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '473710'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '670512'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '12132'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '727035'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '703546'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '713903'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '508693'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '694577'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '655292'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '684262'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '643435'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '694583'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '703892'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '660799'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '674414'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '657508'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '665474'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '695217'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '708811'
# 		No existing records match; adding to recordsToCreate
# 	Processing record w / 'Page ID' === '673702'
# 		No existing records match; adding to recordsToCreate
#
# 9486 records to create
# 6890 records to update
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/yc/vsthw68x7bjckj6tb7_8bpm00000gq/T/ipykernel_28423/4090752144.py in <module>
#      54
#      55 # Perform record creation - typecast = True to crete new Single Select Options
# ---> 56 Table.batch_create(recordsToCreate, typecast=True)
#      57
#      58 # Perform record updates on existing records - typecast = True to crete new Single Select Options
#
# ~/.local/share/virtualenvs/customer_solutions_engineering-W9sAjCr_/lib/python3.10/site-packages/pyairtable/api/table.py in batch_create(self, records, typecast)
#      92         but without ``base_id`` and ``table_name`` arg.
#      93         """
# ---> 94         return super()._batch_create(
#      95             self.base_id, self.table_name, records, typecast=typecast
#      96         )
#
# ~/.local/share/virtualenvs/customer_solutions_engineering-W9sAjCr_/lib/python3.10/site-packages/pyairtable/api/abstract.py in _batch_create(self, base_id, table_name, records, typecast)
#     146         for chunk in self._chunk(records, self.MAX_RECORDS_PER_REQUEST):
#     147             new_records = self._build_batch_record_objects(chunk)
# --> 148             response = self._request(
#     149                 "post",
#     150                 table_url,
#
# ~/.local/share/virtualenvs/customer_solutions_engineering-W9sAjCr_/lib/python3.10/site-packages/pyairtable/api/abstract.py in _request(self, method, url, params, json_data)
#      90
#      91     def _request(self, method: str, url: str, params=None, json_data=None):
# ---> 92         response = self.session.request(
#      93             method, url, params=params, json=json_data, timeout=self.timeout
#      94         )
#
# ~/.local/share/virtualenvs/customer_solutions_engineering-W9sAjCr_/lib/python3.10/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/.local/share/virtualenvs/customer_solutions_engineering-W9sAjCr_/lib/python3.10/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/.local/share/virtualenvs/customer_solutions_engineering-W9sAjCr_/lib/python3.10/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~/.local/share/virtualenvs/customer_solutions_engineering-W9sAjCr_/lib/python3.10/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~/.local/share/virtualenvs/customer_solutions_engineering-W9sAjCr_/lib/python3.10/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/.local/share/virtualenvs/customer_solutions_engineering-W9sAjCr_/lib/python3.10/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/.local/share/virtualenvs/customer_solutions_engineering-W9sAjCr_/lib/python3.10/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py in getresponse(self)
#    1366         try:
#    1367             try:
# -> 1368                 response.begin()
#    1369             except ConnectionError:
#    1370                 self.close()
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py in begin(self)
#     315         # read until we get a non-100 response
#     316         while True:
# --> 317             version, status, reason = self._read_status()
#     318             if status != CONTINUE:
#     319                 break
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py in _read_status(self)
#     276
#     277     def _read_status(self):
# --> 278         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     279         if len(line) > _MAXLINE:
#     280             raise LineTooLong("status line")
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1271                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1272                   self.__class__)
# -> 1273             return self.read(nbytes, buffer)
#    1274         else:
#    1275             return super().recv_into(buffer, nbytes, flags)
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ssl.py in read(self, len, buffer)
#    1127         try:
#    1128             if buffer is not None:
# -> 1129                 return self._sslobj.read(len, buffer)
#    1130             else:
#    1131                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Compare information from DataSource and Airtable
